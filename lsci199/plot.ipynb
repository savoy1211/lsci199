# %%
from h_wordorder import *
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("csv/bigram_model_results_windows1to5_pride_and_prejudice", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df)
df.plot()
df1 = pd.read_csv("csv/bigram_model_results_windows1to5_two_cities", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df1)
df1.plot()
df2 = pd.read_csv("csv/bigram_model_results_windows1to5_moby_dick", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df2)
df2.plot()
df3 = pd.read_csv("csv/bigram_model_results_windows1to5_hard_times", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df3)
df3.plot()

# %%
# Bigram model for windows 1-4 over 'Pride and Prejudice' (character lengths[500000,100000,150000,200000,250000])
df = pd.read_csv("csv/bigram_model_results_window1_prideprejudice", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df)
df.plot()
df2 = pd.read_csv("csv/bigram_model_results_window2_prideprejudice", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df2)
df2.plot()
df3 = pd.read_csv("csv/bigram_model_results_window3_prideprejudice", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df3)
df3.plot()
df4 = pd.read_csv("csv/bigram_model_results_window4_prideprejudice", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df4)
df4.plot()

# %%
# Bigram model for windows 1-4 over 'Two Cities' (character lengths[500000,100000,150000,200000,250000])
df = pd.read_csv("csv/bigram_model_results_window1_two_cities", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df)
df.plot()
df2 = pd.read_csv("csv/bigram_model_results_window2_two_cities", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df2)
df2.plot()
df3 = pd.read_csv("csv/bigram_model_results_window3_two_cities", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df3)
df3.plot()
df4 = pd.read_csv("csv/bigram_model_results_window4_two_cities", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df4)
df4.plot()

# %%
# Bigram model for windows 1-4 over 'Moby Dick' (character lengths[500000,100000,150000,200000,250000])
df = pd.read_csv("csv/bigram_model_results_window1_moby_dick", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df)
df.plot()
df2 = pd.read_csv("csv/bigram_model_results_window2_moby_dick", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df2)
df2.plot()
df3 = pd.read_csv("csv/bigram_model_results_window3_moby_dick", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df3)
df3.plot()
df4 = pd.read_csv("csv/bigram_model_results_window4_moby_dick", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df4)
df4.plot()

# %%
# Bigram model for windows 1-4 over 'Moby Dick' (character lengths[500000,100000,150000,200000,250000])
df = pd.read_csv("csv/bigram_model_results_window1_moby_dick", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df)
df.plot()
df2 = pd.read_csv("csv/bigram_model_results_window2_moby_dick", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df2)
df2.plot()
df3 = pd.read_csv("csv/bigram_model_results_window3_moby_dick", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df3)
df3.plot()
df4 = pd.read_csv("csv/bigram_model_results_window4_moby_dick", index_col=0, parse_dates=True)
# df = df.pivot(index='x', columns='color', values='y')
# print(df4)
df4.plot()
